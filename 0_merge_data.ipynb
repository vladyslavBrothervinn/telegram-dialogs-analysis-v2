# %%
import os
import pandas as pd
import glob

# %%
DIALOGS_DATA_PATH = "../data/dialogs"
DIALOGS_META_DATA_PATH = "../data/dialogs_meta"

MERGED_DATA_PATH = "../data/merged_data"

# %%
# !ls ../data/
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
dialogs_data_files = glob.glob(f"{DIALOGS_DATA_PATH}/*.csv")
dialogs_meta_data_files = glob.glob(f"{DIALOGS_META_DATA_PATH}/*.json")

# %% [markdown]
# ## merging all dialogs_data (csv files) into one

# %%
df_array = []

for d in dialogs_data_files:
    local_df = pd.read_csv(d)
    local_df["dialog_id"] = os.path.basename(d).split(".")[0]
    df_array.append(local_df)
    
df = pd.concat(df_array, ignore_index=True)

# %%
df.shape
df
# df["from_id"].unique()
# Out:
#         Unnamed: 0      id                       date  \
# 0                0  190667  2022-01-03 10:57:14+00:00
# 1                1  190665  2022-01-03 10:55:56+00:00
# 2                2  190664  2022-01-03 10:55:15+00:00
# 3                3  190663  2022-01-03 10:53:34+00:00
# 4                4  124727  2021-04-18 15:07:35+00:00
# ...            ...     ...                        ...
# 258578          83   66714  2020-03-19 13:16:15+00:00
# 258579          84   66713  2020-03-19 13:16:15+00:00
# 258580          85   66712  2020-03-19 13:16:15+00:00
# 258581          86   66711  2020-03-19 13:16:07+00:00
# 258582          87   66710  2020-03-19 13:15:33+00:00
#
#                             from_id       to_id fwd_from  \
# 0       PeerUser(user_id=535972821)  1016910980      NaN
# 1                               NaN   535972821      NaN
# 2       PeerUser(user_id=535972821)  1016910980      NaN
# 3                               NaN   535972821      NaN
# 4       PeerUser(user_id=535972821)  1016910980      NaN
# ...                             ...         ...      ...
# 258578  PeerUser(user_id=535972821)   989999783      NaN
# 258579  PeerUser(user_id=535972821)   989999783      NaN
# 258580  PeerUser(user_id=535972821)   989999783      NaN
# 258581  PeerUser(user_id=535972821)   989999783      NaN
# 258582  PeerUser(user_id=535972821)   989999783      NaN
#
#                                                   message   type  duration  \
# 0                                                Ти права   text       NaN
# 1             Бачиш, однокласники про тебе не забувають.)   text       NaN
# 2                                     Привіііт, дякую!!!)   text       NaN
# 3       Привіт. Вітаю з Днем народження. 🎉🎉🎉\nБажаю ща...   text       NaN
# 4                                                    Ахах   text       NaN
# ...                                                   ...    ...       ...
# 258578                                                NaN  photo       NaN
# 258579                                                NaN  photo       NaN
# 258580                                                NaN  photo       NaN
# 258581  Зараз відправлю вам фото з останнім домашнім з...   text       NaN
# 258582                                        Добрий день   text       NaN
#
#        reactions   dialog_id
# 0             {}  1016910980
# 1             {}  1016910980
# 2             {}  1016910980
# 3             {}  1016910980
# 4             {}  1016910980
# ...          ...         ...
# 258578        {}   989999783
# 258579        {}   989999783
# 258580        {}   989999783
# 258581        {}   989999783
# 258582        {}   989999783
#
# [258583 rows x 11 columns]

# %%
if not os.path.isdir(MERGED_DATA_PATH):
    os.mkdir(MERGED_DATA_PATH)

if "Unnamed: 0" in df:
    df = df.drop(["Unnamed: 0"], axis=True)
    
df.to_csv(f"{MERGED_DATA_PATH}/dialogs_data_all.csv", index=False)

# %%
df.shape
# Out:
# (258583, 10)

# %%
df.head(10)
# Out:
#        id                       date                      from_id       to_id  \
# 0  190667  2022-01-03 10:57:14+00:00  PeerUser(user_id=535972821)  1016910980
# 1  190665  2022-01-03 10:55:56+00:00                          NaN   535972821
# 2  190664  2022-01-03 10:55:15+00:00  PeerUser(user_id=535972821)  1016910980
# 3  190663  2022-01-03 10:53:34+00:00                          NaN   535972821
# 4  124727  2021-04-18 15:07:35+00:00  PeerUser(user_id=535972821)  1016910980
# 5  124726  2021-04-18 15:07:07+00:00                          NaN   535972821
# 6  124725  2021-04-18 15:05:38+00:00                          NaN   535972821
# 7  124724  2021-04-18 15:04:51+00:00  PeerUser(user_id=535972821)  1016910980
# 8  124723  2021-04-18 15:04:05+00:00                          NaN   535972821
# 9  124722  2021-04-18 15:03:47+00:00                          NaN   535972821
#
#   fwd_from                                            message  type  duration  \
# 0      NaN                                           Ти права  text       NaN
# 1      NaN        Бачиш, однокласники про тебе не забувають.)  text       NaN
# 2      NaN                                Привіііт, дякую!!!)  text       NaN
# 3      NaN  Привіт. Вітаю з Днем народження. 🎉🎉🎉\nБажаю ща...  text       NaN
# 4      NaN                                               Ахах  text       NaN
# 5      NaN  Просто я крім себе, ще Ані роботу виконувала, ...  text       NaN
# 6      NaN                                       Ясно. Дякую.  text       NaN
# 7      NaN                               Своим именем и датой  text       NaN
# 8      NaN                               А як ти файл назвав?  text       NaN
# 9      NaN                                              Жаль.  text       NaN
#
#   reactions   dialog_id
# 0        {}  1016910980
# 1        {}  1016910980
# 2        {}  1016910980
# 3        {}  1016910980
# 4        {}  1016910980
# 5        {}  1016910980
# 6        {}  1016910980
# 7        {}  1016910980
# 8        {}  1016910980
# 9        {}  1016910980

# %%
min(df["date"]),max(df["date"])
# Out:
# ('2017-12-29 21:39:13+00:00', '2023-10-26 11:49:05+00:00')

# %%
df.groupby(["type"])["type"].count()
# Out:
# type
# photo       22726
# sticker      2695
# text       219573
# video        5675
# voice        7914
# Name: type, dtype: int64

# %%
df.groupby(["type"])["duration"].sum()

df.groupby(["type"])["duration"].describe()
# Out:
#           count       mean         std  min  25%   50%   75%     max
# type
# photo       0.0        NaN         NaN  NaN  NaN   NaN   NaN     NaN
# sticker     0.0        NaN         NaN  NaN  NaN   NaN   NaN     NaN
# text        0.0        NaN         NaN  NaN  NaN   NaN   NaN     NaN
# video    5675.0  49.961233  285.601795  0.0  7.0  14.0  29.0  6250.0
# voice    7914.0  27.965631   57.605138  0.0  5.0  13.0  29.0  1296.0

# %% [markdown]
# ## merging all dialogs_meta_data (json files) into one

# %%
df_array = []

for d in dialogs_meta_data_files:
    local_df = pd.read_json(d)
    local_df = local_df.rename({'id': 'dialog_id'}, axis=1)
    df_array.append(local_df)
    
df_meta = pd.concat(df_array, ignore_index=True)

# %%
df_meta.to_csv(f"{MERGED_DATA_PATH}/dialogs_users_all.csv", index=False)

# %%
df_meta.shape

# %%
df_meta.head(10)

# %%
df_meta.groupby(["type"])["type"].count()
